# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("C:/Users/zaferisk/Desktop/starbucks.csv",index_col=0)

# %%
df.groupby("type")["item"].count().plot()
plt.title("TYPES")
plt.text(0.,60,"PRODUCT TYPES",bbox=dict(facecolor="green",alpha=1))
plt.show()

# %%
sns.catplot(kind="bar",x="type",y="carb",data=df)
plt.title("calorie values")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
## calories and fat correlation
plt.title("calories and fat correlation")
sns.scatterplot(x="calories",y="fat",data=df,s=15,edgecolor="blue")
# Out:
# <AxesSubplot:title={'center':'calories and fat correlation'}, xlabel='calories', ylabel='fat'>

# %%
## ürünün hangi kategoriye sahip olduğunu tahmin ettirmeye çalışacağız
# decsiontree kullanarak yapacağız


from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

x =df[["calories","fat","carb","fiber","protein"]]
y =df["type"]


x_train,x_test, y_train,y_test = train_test_split(x, y,test_size=0.2,random_state=0)

model=DecisionTreeClassifier()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)

print("accuracy",accuracy)
# Out:
# accuracy 0.625

# %%
##prediction

prediction=model.predict([[100,4,22,11,29]])

print(prediction)
# Out:
# ['hot breakfast']
# C:\Anaconda3\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
